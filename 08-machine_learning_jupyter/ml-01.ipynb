# %% [markdown]
# matppotlib example:

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

# print(x)
# print(ys)

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='r', alpha=0.6)

plt.title("Data Visualization")
plt.show()

# %%
data = np.genfromtxt('data/PewDiePie.csv', delimiter=',')
print(np.shape(data))
# print(data.dtypes)
print(len(data))
y = [data[i][1] for i in range(len(data))]
y10 = y[1:21]
print(y10)
plt.plot(range(20),y10)
plt.show()
plt.hist(y, bins=10, range=(0, 80000))
plt.title("Histogram")
plt.show()
# Out:
# (21, 2)
# 21
# [71915.0, 48270.0, 47746.0, 42276.0, 36867.0, 28722.0, 29794.0, 33125.0, 27877.0, 30675.0, 32450.0, 45714.0, 59377.0, 42289.0, 36002.0, 25872.0, 31623.0, 46504.0, 49421.0, 27844.0]
